# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('datanyar1.xlsx')

# %%
df.head()
# Out:
#    RPM_Feeder  Amp_Press  Temp_Cond_1  Temp_Cond_2  Temp_Cond_3  \
# 0         186       97.1         69.4         73.3         76.3
# 1         204       97.2         70.6         75.5         80.2
# 2         204       97.2         70.6         75.5         80.2
# 3         203       96.5         68.3         73.4         79.1
# 4         200       95.7         68.2         73.7         80.9
#
#    Temp_Post_Pellet  WS_Dryer
# 0               115       0.6
# 1               115       0.7
# 2               115       0.5
# 3               115       0.5
# 4               115       0.5

# %%
df.to_csv('datanyar1.csv', index=False)

# %%
df=pd.read_csv('datanyar1.csv')

# %%
df.head()
# Out:
#    RPM_Feeder  Amp_Press  Temp_Cond_1  Temp_Cond_2  Temp_Cond_3  \
# 0         186       97.1         69.4         73.3         76.3
# 1         204       97.2         70.6         75.5         80.2
# 2         204       97.2         70.6         75.5         80.2
# 3         203       96.5         68.3         73.4         79.1
# 4         200       95.7         68.2         73.7         80.9
#
#    Temp_Post_Pellet  WS_Dryer
# 0               115       0.6
# 1               115       0.7
# 2               115       0.5
# 3               115       0.5
# 4               115       0.5

# %%
df.head()
# Out:
#    RPM_Feeder  Amp_Press  Temp_Cond_1  Temp_Cond_2  Temp_Cond_3  \
# 0         186       97.1         69.4         73.3         76.3
# 1         204       97.2         70.6         75.5         80.2
# 2         204       97.2         70.6         75.5         80.2
# 3         203       96.5         68.3         73.4         79.1
# 4         200       95.7         68.2         73.7         80.9
#
#    Temp_Post_Pellet  WS_Dryer
# 0               115       0.6
# 1               115       0.7
# 2               115       0.5
# 3               115       0.5
# 4               115       0.5

# %%
print (df.dtypes)
# Out:
# RPM_Feeder            int64
# Amp_Press           float64
# Temp_Cond_1         float64
# Temp_Cond_2         float64
# Temp_Cond_3         float64
# Temp_Post_Pellet      int64
# WS_Dryer            float64
# dtype: object

# %%
df = df.astype(float)

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['RPM_Feeder'], shade=True, color='purple')
plt.title('Distribusi KDE RPM Feeder')
plt.xlabel('RPM_Feeder')
plt.ylabel('Kepadatan')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Amp_Press'], shade=True, color='red')
plt.title('Distribusi KDE Ampere Press')
plt.xlabel('Ampere Press')
plt.ylabel('Kepadatan')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Temp_Cond_1'], shade=True, color='green')
plt.title('Distribusi KDE Temp_Cond_1')
plt.xlabel('Temp_Cond_1')
plt.ylabel('Kepadatan')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Temp_Cond_2'], shade=True, color='yellow')
plt.title('Distribusi KDE Temp_Cond_2')
plt.xlabel('Temp_Cond_2')
plt.ylabel('Kepadatan')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Temp_Cond_3'], shade=True, color='blue')
plt.title('Distribusi KDE Temp_Cond_3')
plt.xlabel('Temp_Cond_3')
plt.ylabel('Kepadatan')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(df['Temp_Post_Pellet'], shade=True, color='orange')
plt.title('Distribusi KDE Temperature Post Pellet')
plt.xlabel('Temp_Post_Pellet')
plt.ylabel('Kepadatan')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['RPM_Feeder'], shade=True, color='purple')
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Amp_Press'], shade=True, color='red')
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:16: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Temp_Cond_1'], shade=True, color='green')
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Temp_Cond_2'], shade=True, color='yellow')
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:30: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Temp_Cond_3'], shade=True, color='blue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_10936\820877054.py:37: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Temp_Post_Pellet'], shade=True, color='orange')

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df.corr(), vmax=1, vmin=-1, center=0, cmap="Spectral", annot=True)
# Out:
# <Axes: >

# %%
# Membuat dan melatih model regresi linier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# Memisahkan fitur (X) dan target (y)
X = df[['RPM_Feeder', 'Amp_Press', 'Temp_Cond_1', 'Temp_Cond_2', 'Temp_Cond_3', 'Temp_Post_Pellet']]  # Fitur
y = df['WS_Dryer']  # Target

# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Instead of LinearRegression, use Lasso or Ridge for regularization.
# Lasso uses L1 regularization, while Ridge uses L2 regularization.
from sklearn.linear_model import Lasso  # or from sklearn.linear_model import Ridge

# Create and train the Lasso model
model = Lasso(alpha=0.1)  # alpha is the regularization strength, equivalent to C in other models
# If using Ridge, it would be: model = Ridge(alpha=1.0)

model.fit(X_train, y_train) # Changed lasso_model to model
# Out:
# Lasso(alpha=0.1)

# %%
# Memprediksi data uji
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error (MSE): {mse}')
print(f'R-squared: {r2}')
print('Koefisien dari model Lasso:', model.coef_)
# Out:
# Mean Squared Error (MSE): 0.008529485430231694
# R-squared: -2.8382684436042633
# Koefisien dari model Lasso: [ 0.00288728 -0.         -0.         -0.         -0.          0.        ]

# %%
# Menampilkan hasil prediksi dan nilai asli
print("\nPrediksi WS:")
print(y_pred)

# Menampilkan nilai R^2 (koefisien determinasi)
import statsmodels.api as sm

print(f"\nNilai R^2: {model.score(X_test, y_test):.4f}")
# Out:
# Prediksi WS:
# [0.63479465 0.58571092 0.59148548]
#
# Nilai R^2: -2.8383

# %%
# Evaluasi model: MSE, RMSE, dan MAE
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = metrics.mean_absolute_error(y_test, y_pred)

print(f"\nMean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Squared Error (MSE): 0.01
# Root Mean Squared Error (RMSE): 0.09
# Mean Absolute Error (MAE): 0.08

# %%
# Plotting hasil prediksi vs nilai asli
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.title("Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
# Hitung Mean Squared Error
from sklearn.metrics import mean_squared_error
mse_lasso = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (Lasso Regression):", mse_lasso)

# Koefisien yang dihasilkan oleh model
print("Koefisien Lasso Regression:", model.coef_)
# Out:
# Mean Squared Error (Lasso Regression): 0.008529485430231694
# Koefisien Lasso Regression: [ 0.00288728 -0.         -0.         -0.         -0.          0.        ]

# %%
# Plotting hasil prediksi vs nilai asli
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.title("Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
    # Input data dari pengguna
    print("Masukkan Data:")

    RPM_Feeder = float(input("Masukkan data RPM Feeder: "))
    Amp_Press = float(input("Masukkan data Amp Press: "))
    Temp_Cond_1 = float(input("Masukkan data Temp Cond 1: "))
    Temp_Cond_2 = float(input("Masukkan data Temp Cond 2: "))
    Temp_Cond_3 = float(input("Masukkan data Temp Cond 3: "))
    Temp_Post_Pellet = float(input("Masukkan data Temp Post Pellet: "))

    # Membuat array fitur dari input pengguna
    input_data = np.array([[RPM_Feeder, Amp_Press, Temp_Cond_1, Temp_Cond_2, Temp_Cond_3, Temp_Post_Pellet]])

    # Memuat model yang sudah dilatih (misalnya menggunakan pickle)
    # Inisialisasi model untuk contoh ini (gunakan model yang telah disimpan dengan pickle)
    # with open(model_filename, 'rb') as f:
    #     model = pickle.load(f)

    # Prediksi harga menggunakan model
    prediksi = model.predict(input_data)

    # Menampilkan hasil prediksi
    # Extract the predicted value as a float before formatting
    # Added precision to the format specifier (e.g., .0f for 0 decimal places)
    print('Prediksi WS adalah:', prediksi) # Changed from {predicted_value:,.f} to {predicted_value:,.0f}
# Out:
# Masukkan Data:
# Masukkan data RPM Feeder: 100
# Masukkan data Amp Press: 100
# Masukkan data Temp Cond 1: 100
# Masukkan data Temp Cond 2: 100
# Masukkan data Temp Cond 3: 100
# Masukkan data Temp Post Pellet: 100
# Prediksi WS adalah: [0.34317954]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # import pickle

# %%
import pickle

filename = 'Prediksinyar.sav'
pickle.dump(model, open(filename, 'wb'))
